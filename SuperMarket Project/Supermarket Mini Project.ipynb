# %%
import numpy as np # inear algebra
import os # accessing directory structure
import pandas as pd # data processing

# %%
import matplotlib.pyplot as plt
import seaborn as sea

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df=pd.read_csv("supermarket_sales - Sheet1.csv") # Reads data from csv file and stores it in dataframe

# %%
df # Shows dataframe of supermarket data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.head() # Shows the first 5 rows of each column
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.tail() # Shows the last 5 rows of each column
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
# ...

# %%
df.sample(10) # Gets a random sample of 10 rows from the dataframe
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 187  732-04-5373      B   Mandalay        Member    Male
# 732  756-49-0168      A     Yangon        Member    Male
# 946  859-97-6048      C  Naypyitaw        Member    Male
# 286  593-95-4461      C  Naypyitaw        Member    Male
# 897  409-49-6995      C  Naypyitaw        Member  Female
# 479  575-67-1508      A     Yangon        Normal    Male
# 544  841-18-8232      B   Mandalay        Normal  Female
# 724  434-35-9162      B   Mandalay        Member    Male
# 669  679-22-6530      B   Mandalay        Normal  Female
# 76   263-10-3913      C  Naypyitaw        Member    Male
#
#                Product line  Unit price  Quantity  Tax 5%    Total       Date  \
# 187      Home and lifestyle       46.47         4   9.294  195.174   2/8/2019
# 732     Fashion accessories       19.70         1   0.985   20.685   2/8/2019
# 946  Electronic accessories       84.25         2   8.425  176.925  3/26/2019
# ...

# %%
type(df) # Shows data type of data frame
# Out:
# pandas.core.frame.DataFrame

# %%
df.info() # Shows all data types for the columns and their names
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.shape[0] # Number of rows
# Out:
# 1000

# %%
df.shape[1] # Number of columns
# Out:
# 17

# %%
df.describe() # Shows how many values there are of each int column, as well as certain statistics about said columns
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
print(df.isnull()) # Shows if values are null in the dataframe
# Out:
#      Invoice ID  Branch   City  Customer type  Gender  Product line  \
# 0         False   False  False          False   False         False
# 1         False   False  False          False   False         False
# 2         False   False  False          False   False         False
# 3         False   False  False          False   False         False
# 4         False   False  False          False   False         False
# ..          ...     ...    ...            ...     ...           ...
# 995       False   False  False          False   False         False
# 996       False   False  False          False   False         False
# 997       False   False  False          False   False         False
# 998       False   False  False          False   False         False
# 999       False   False  False          False   False         False
#
#      Unit price  Quantity  Tax 5%  Total   Date   Time  Payment   cogs  \
# 0         False     False   False  False  False  False    False  False
# ...

# %%
print(df.isnull().sum()) # Adds up all null values in the dataframe for each column
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.to_excel('SuperMarket Mini Project.xlsx', index = False) # Sends the data from the dataframe to a microsoft excel file for future use

# %%
sea.set_style(style='dark') # Sets the style for the chart to dark mode
sea.countplot(x='City', data=df).set_title('City Count') # Creates a histogram like graph showing the count of cities in the data frame
# Out:
# Text(0.5, 1.0, 'City Count')

# %%
sea.countplot(x='Gender', data=df).set_title('Genders') # Creates a histogram like graph showing the count of genders in the data frame
# Out:
# Text(0.5, 1.0, 'Genders')

# %%
sea.displot(x= 'Rating' ,data=df) # Creates a distribution chart showing the amount of each rating within the dataframe. Default histogram mode here
# Out:
# C:\Users\Dominic\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sea.displot(x= 'Rating' ,data=df, kind='ecdf') # Shows the above distribution chart in a different form. Proportion distribution functions used for this one. Not using the base histogram mode
# Out:
# C:\Users\Dominic\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sea.displot(x='cogs', data=df, kde = True) # Shows the above distribution chart in a different form. Default Histogram mode here but with a KDE being used.
# Out:
# C:\Users\Dominic\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sea.scatterplot(data = df, x='Unit price', y='Rating') # Scatterplot used to show the comparison between the costs of certain products and their reviews
# Out:
# <Axes: xlabel='Unit price', ylabel='Rating'>

# %%
sea.barplot(data=df, x = 'Branch', y='gross income') # Creates a barplot showing how much each branch made in terms of gross income
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %%
sea.barplot(data=df, x = 'Product line', y='Unit price') # Creates a barplot showing the different product line types and the highest unit price for each
# Out:
# <Axes: xlabel='Product line', ylabel='Unit price'>
