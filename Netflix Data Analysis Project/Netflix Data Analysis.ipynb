# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import os

for dirname, _, filenames in os.walk('/Downloads'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
netflix_df = pd.read_csv("most-popular.csv")

# %%
netflix_df
# Out:
#                category  rank                           show_title  \
# 0       Films (English)     1                           Red Notice
# 1       Films (English)     2                        Don't Look Up
# 2       Films (English)     3                     The Adam Project
# 3       Films (English)     4                             Bird Box
# 4       Films (English)     5                         The Gray Man
# 5       Films (English)     6                     We Can Be Heroes
# 6       Films (English)     7                           The Mother
# 7       Films (English)     8    Glass Onion: A Knives Out Mystery
# 8       Films (English)     9                           Extraction
# 9       Films (English)    10                         Extraction 2
# 10  Films (Non-English)     1                                Troll
# 11  Films (Non-English)     2                              Nowhere
# 12  Films (Non-English)     3                         The Platform
# ...

# %%
netflix_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   category                    40 non-null     object
#  1   rank                        40 non-null     int64
#  2   show_title                  40 non-null     object
#  3   season_title                19 non-null     object
#  4   hours_viewed_first_91_days  40 non-null     int64
#  5   runtime                     40 non-null     float64
#  6   views_first_91_days         40 non-null     int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 2.3+ KB

# %%
netflix_df['category'].value_counts()
# Out:
# category
# Films (English)        10
# Films (Non-English)    10
# TV (English)           10
# TV (Non-English)       10
# Name: count, dtype: int64

# %%
netflix_df['season_title'].value_counts()
# Out:
# season_title
# Wednesday: Season 1                          1
# Money Heist: Part 4                          1
# Dear Child: Limited Series                   1
# All of Us Are Dead: Season 1                 1
# Who Killed Sara?: Season 1                   1
# Lupin: Part 2                                1
# Money Heist: Part 3                          1
# Money Heist: Part 5                          1
# Lupin: Part 1                                1
# Squid Game: Season 1                         1
# Stranger Things 4                            1
# The Witcher: Season 1                        1
# Bridgerton: Season 2                         1
# Stranger Things 3                            1
# The Night Agent: Season 1                    1
# The Queen's Gambit: Limited Series           1
# Bridgerton: Season 1                         1
# DAHMER: Monster: The Jeffrey Dahmer Story    1
# Elite: Season 3                              1
# Name: count, dtype: int64

# %%
netflix_df['category']
# Out:
# 0         Films (English)
# 1         Films (English)
# 2         Films (English)
# 3         Films (English)
# 4         Films (English)
# 5         Films (English)
# 6         Films (English)
# 7         Films (English)
# 8         Films (English)
# 9         Films (English)
# 10    Films (Non-English)
# 11    Films (Non-English)
# 12    Films (Non-English)
# 13    Films (Non-English)
# 14    Films (Non-English)
# 15    Films (Non-English)
# 16    Films (Non-English)
# 17    Films (Non-English)
# 18    Films (Non-English)
# 19    Films (Non-English)
# 20           TV (English)
# 21           TV (English)
# 22           TV (English)
# 23           TV (English)
# 24           TV (English)
# 25           TV (English)
# 26           TV (English)
# 27           TV (English)
# 28           TV (English)
# 29           TV (English)
# 30       TV (Non-English)
# 31       TV (Non-English)
# 32       TV (Non-English)
# 33       TV (Non-English)
# 34       TV (Non-English)
# ...

# %%
netflix_df['season_title']
# Out:
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 17                                          NaN
# 18                                          NaN
# 19                                          NaN
# ...

# %%
netflix_df['show_title']
# Out:
# 0                              Red Notice
# 1                           Don't Look Up
# 2                        The Adam Project
# 3                                Bird Box
# 4                            The Gray Man
# 5                        We Can Be Heroes
# 6                              The Mother
# 7       Glass Onion: A Knives Out Mystery
# 8                              Extraction
# 9                            Extraction 2
# 10                                  Troll
# 11                                Nowhere
# 12                           The Platform
# 13                      Through My Window
# 14                                    AKA
# 15                          Blood Red Sky
# 16                    My Name Is Vendetta
# 17                             Black Crab
# 18         All Quiet on the Western Front
# 19                             Below Zero
# 20                              Wednesday
# 21                        Stranger Things
# ...

# %%
netflix_df['runtime']
# Out:
# 0      1.9667
# 1      2.3833
# 2      1.7833
# 3      2.0667
# 4      2.1500
# 5      1.6833
# 6      1.9500
# 7      2.3500
# 8      1.9667
# 9      2.0667
# 10     1.7333
# 11     1.8167
# 12     1.5667
# 13     1.9000
# 14     2.0667
# 15     2.0500
# 16     1.5333
# 17     1.9167
# 18     2.4833
# 19     1.7833
# 20     6.8167
# 21    13.0667
# 22     8.9167
# 23     8.2000
# 24     6.6167
# 25     8.1833
# 26     7.5500
# 27     8.5000
# 28     8.0000
# 29     6.4833
# 30     8.3167
# 31     6.7000
# 32     3.9833
# 33     9.0833
# 34     6.5000
# 35     3.7833
# 36     6.7167
# 37    12.2333
# 38     4.8167
# 39     6.7000
# Name: runtime, dtype: float64

# %%
netflix_df.sort_values(by="views_first_91_days")
# Out:
#                category  rank                           show_title  \
# 19  Films (Non-English)    10                           Below Zero
# 39     TV (Non-English)    10                                Elite
# 38     TV (Non-English)     9                           Dear Child
# 18  Films (Non-English)     9       All Quiet on the Western Front
# 17  Films (Non-English)     8                           Black Crab
# 37     TV (Non-English)     8                   All of Us Are Dead
# 16  Films (Non-English)     7                  My Name Is Vendetta
# 36     TV (Non-English)     7                     Who Killed Sara?
# 14  Films (Non-English)     5                                  AKA
# 15  Films (Non-English)     6                        Blood Red Sky
# 13  Films (Non-English)     4                    Through My Window
# 35     TV (Non-English)     6                                Lupin
# 34     TV (Non-English)     5                          Money Heist
# ...

# %%
Runtime_Sorted = netflix_df.sort_values(by='runtime')
Runtime_Sorted
# Out:
#                category  rank                           show_title  \
# 16  Films (Non-English)     7                  My Name Is Vendetta
# 12  Films (Non-English)     3                         The Platform
# 5       Films (English)     6                     We Can Be Heroes
# 10  Films (Non-English)     1                                Troll
# 19  Films (Non-English)    10                           Below Zero
# 2       Films (English)     3                     The Adam Project
# 11  Films (Non-English)     2                              Nowhere
# 13  Films (Non-English)     4                    Through My Window
# 17  Films (Non-English)     8                           Black Crab
# 6       Films (English)     7                           The Mother
# 0       Films (English)     1                           Red Notice
# 8       Films (English)     9                           Extraction
# 15  Films (Non-English)     6                        Blood Red Sky
# ...

# %%
Runtime_Sorted[['show_title', 'runtime']]
# Out:
#                              show_title  runtime
# 16                  My Name Is Vendetta   1.5333
# 12                         The Platform   1.5667
# 5                      We Can Be Heroes   1.6833
# 10                                Troll   1.7333
# 19                           Below Zero   1.7833
# 2                      The Adam Project   1.7833
# 11                              Nowhere   1.8167
# 13                    Through My Window   1.9000
# 17                           Black Crab   1.9167
# 6                            The Mother   1.9500
# 0                            Red Notice   1.9667
# 8                            Extraction   1.9667
# 15                        Blood Red Sky   2.0500
# 14                                  AKA   2.0667
# 3                              Bird Box   2.0667
# 9                          Extraction 2   2.0667
# 4                          The Gray Man   2.1500
# 7     Glass Onion: A Knives Out Mystery   2.3500
# ...

# %%
Runtime_Sorted[['show_title', 'runtime']].head()
# Out:
#              show_title  runtime
# 16  My Name Is Vendetta   1.5333
# 12         The Platform   1.5667
# 5      We Can Be Heroes   1.6833
# 10                Troll   1.7333
# 19           Below Zero   1.7833

# %%
Runtime_Sorted[['show_title', 'runtime']].tail()
# Out:
#             show_title  runtime
# 27          Bridgerton   8.5000
# 22              DAHMER   8.9167
# 33         Money Heist   9.0833
# 37  All of Us Are Dead  12.2333
# 21     Stranger Things  13.0667

# %%
Runtime_Sorted[['category', 'views_first_91_days']]
# Out:
#                category  views_first_91_days
# 16  Films (Non-English)             56400000
# 12  Films (Non-English)             82800000
# 5       Films (English)            137300000
# 10  Films (Non-English)            103000000
# 19  Films (Non-English)             48600000
# 2       Films (English)            157600000
# 11  Films (Non-English)             83700000
# 13  Films (Non-English)             61100000
# 17  Films (Non-English)             53900000
# 6       Films (English)            136400000
# 0       Films (English)            230900000
# 8       Films (English)            135700000
# 15  Films (Non-English)             60900000
# 14  Films (Non-English)             60900000
# 3       Films (English)            157400000
# 9       Films (English)            134900000
# 4       Films (English)            139300000
# 7       Films (English)            136300000
# 1       Films (English)            171400000
# 18  Films (Non-English)             52100000
# ...

# %%
average_views_category = netflix_df.groupby('category')['views_first_91_days'].mean()
average_views_category
# Out:
# category
# Films (English)        153720000.0
# Films (Non-English)     66340000.0
# TV (English)           118560000.0
# TV (Non-English)        93310000.0
# Name: views_first_91_days, dtype: float64

# %%
most_view_category = netflix_df.groupby('category')['views_first_91_days'].sum()
most_view_category.sort_values(ascending = False)
# Out:
# category
# Films (English)        1537200000
# TV (English)           1185600000
# TV (Non-English)        933100000
# Films (Non-English)     663400000
# Name: views_first_91_days, dtype: int64

# %%
plt.bar(x = Runtime_Sorted["category"], height = Runtime_Sorted['runtime'], color = "violet")
plt.title("Runtime based on Category")
plt.xlabel("Category", fontweight = 'bold')
plt.ylabel("Runtime in Hours", fontweight = 'bold')

plt.show()
